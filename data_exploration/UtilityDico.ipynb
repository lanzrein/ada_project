# %%
import pandas as pd
import numpy as np
import scipy as scp
import geopy # pip install geopy if necessary
import seaborn as sns # for visualization

# %%
data = pd.read_csv('../openfoodfacts.csv',delimiter='\t',low_memory=False)

# %%
print(data.shape)
# Out:
# (681602, 173)

# %%
data["countries_en"].value_counts().shape
# Out:
# (1361,)

# %%
country_count = data["countries_en"].value_counts()[0:15]

sns.set(style="whitegrid")
sns.barplot(y=country_count.index, x=country_count.values)

# %%
us_product = data[data["countries_en"]=="United States"]
sel = ['categories_en', 'main_category_en', 'labels_en', 'origins_tags', 'manufacturing_places_tags', 
       'first_packaging_code_geo', 'countries_en']
us_product = us_product[sel]
us_product.head()
# Out:
#    categories_en main_category_en labels_en origins_tags  \
# 34           NaN              NaN       NaN          NaN
# 35           NaN              NaN       NaN          NaN
# 62           NaN              NaN       NaN          NaN
# 63           NaN              NaN       NaN          NaN
# 64           NaN              NaN       NaN          NaN
#
#    manufacturing_places_tags first_packaging_code_geo   countries_en
# 34                       NaN                      NaN  United States
# 35                       NaN                      NaN  United States
# 62                       NaN                      NaN  United States
# 63                       NaN                      NaN  United States
# 64                       NaN                      NaN  United States

# %% [markdown]
# Data from US are very incomplete ==> won't be useful for the analysis

# %% [markdown]
# # Data for distance computation

# %%
#a = ~data["first_packaging_code_geo"].isnull() # 27572
b = ~data["origins_tags"].isnull()
c = ~data["manufacturing_places_tags"].isnull()

sele = b | c  # 88001

data_loc = data[sele] # 57688 (88001)
# print(data_loc.shape) # (88001, 173)

sel = ['categories_en', 'main_category_en', 'labels_en', 'origins_tags', 'manufacturing_places_tags', 
       'first_packaging_code_geo', 'countries_en']

data_loc = data_loc[sel]
data_loc
# Out:
#                                             categories_en  \
# 106                                   Dietary supplements
# 251     Meals,Meat-based products,Meals with meat,Poul...
# 254     Plant-based foods and beverages,Plant-based fo...
# 264             Sugary snacks,Biscuits and cakes,Pastries
# 269     Plant-based foods and beverages,Plant-based fo...
# 274             Sugary snacks,Biscuits and cakes,Pastries
# 285                                           fr:Boulange
# 289     Beverages,Carbonated drinks,Sodas,Sugared beve...
# 292     Sugary snacks,Biscuits and cakes,Biscuits,Shor...
# 296     Meals,Pizzas pies and quiches,Quiches,Lorraine...
# 297               Meats,Poultries,Chickens,Cooked chicken
# 299                 Sugary snacks,Confectioneries,Candies
# 305     Plant-based foods and beverages,Beverages,Plan...
# 346             Sugary snacks,Biscuits and cakes,Pastries
# 348                                          Chicken-feet
# 356     Beverages,Alcoholic beverages,Wines,Wines from...
# 383     Plant-based foods and beverages,Plant-based fo...
# 405                  Desserts,Puddings,Christmas Puddings
# 406     Sugary snacks,Desserts,Biscuits and cakes,Cake...
# 410                                                   NaN
# 508     Plant-based foods and beverages,Plant-based fo...
# 516                  Groceries,Condiments,Sauces,Mustards
# 526     Sugary snacks,Desserts,Biscuits and cakes,Cake...
# 545     Plant-based foods and beverages,Plant-based fo...
# 564     Dietary supplements,Bodybuilding supplements,P...
# 565     Dietary supplements,Bodybuilding supplements,P...
# 576     Dietary supplements,Bodybuilding supplements,P...
# 582     Sugary snacks,Biscuits and cakes,Cakes,fr:Cake...
# 587     Sugary snacks,Desserts,Biscuits and cakes,Cake...
# 588                                            Meats,Pork
# ...                                                   ...
# 681180  Plant-based foods and beverages,Plant-based fo...
# 681193        Aperitif,Chips,Chips-et-frites,Snacks-sales
# 681204                                fr:Boissons-au-soja
# 681235                                                NaN
# 681243                                   es:Sauce-a-l-ail
# 681253  Sugary snacks,Biscuits and cakes,Biscuits,Bisc...
# 681290  Canned foods,Seafood,Fishes,Canned fishes,Tuna...
# 681304                   Groceries,Sauces,Salad dressings
# 681305                   Groceries,Sauces,Salad dressings
# 681338                                         Sandwiches
# 681356  Beverages,Waters,Non-sugared beverages,Non-Alc...
# 681357                       Sugary snacks,Popcorn,Snacks
# 681377                             Seafood,Fishes,Salmons
# 681422         fr:Attieke,fr:Manioc,fr:Semoules-de-manioc
# 681424  Beverages,Alcoholic beverages,Artisan products...
# 681426    Beverages,Alcoholic beverages,Beers,Wheat beers
# 681427  Beverages,Alcoholic beverages,Artisan products...
# 681449  Plant-based foods and beverages,Beverages,Plan...
# 681463  Plant-based foods and beverages,Plant-based fo...
# 681472                                                NaN
# 681474  Plant-based foods and beverages,Plant-based fo...
# 681491         Beverages,Alcoholic beverages,Beers,Lagers
# 681493  Sugary snacks,Biscuits and cakes,Biscuits,Choc...
# 681502              Desserts,Frozen foods,Frozen desserts
# 681514  Spreads,Breakfasts,Sweet spreads,Bee products,...
# 681525  Dairies,Fermented foods,Fermented milk product...
# 681535  Beverages,Alcoholic beverages,Wines,Wines from...
# 681537                                          pl:Szprot
# 681538  Plant-based foods and beverages,Beverages,Plan...
# 681585  Plant-based foods and beverages,Plant-based fo...
#
#                        main_category_en  \
# 106                 Dietary supplements
# 251                               Meals
# 254     Plant-based foods and beverages
# 264                       Sugary snacks
# 269     Plant-based foods and beverages
# 274                       Sugary snacks
# 285                         fr:Boulange
# 289                           Beverages
# 292                       Sugary snacks
# 296                               Meals
# 297                               Meats
# 299                       Sugary snacks
# 305                           Beverages
# 346                       Sugary snacks
# 348                        Chicken-feet
# 356                           Beverages
# 383     Plant-based foods and beverages
# 405                            Desserts
# 406                       Sugary snacks
# 410                                 NaN
# 508     Plant-based foods and beverages
# 516                           Groceries
# 526                       Sugary snacks
# 545     Plant-based foods and beverages
# 564                 Dietary supplements
# 565                 Dietary supplements
# 576                 Dietary supplements
# 582                       Sugary snacks
# 587                       Sugary snacks
# 588                               Meats
# ...                                 ...
# 681180  Plant-based foods and beverages
# 681193                         Aperitif
# 681204              fr:Boissons-au-soja
# 681235                              NaN
# 681243                 es:Sauce-a-l-ail
# 681253                    Sugary snacks
# 681290                     Canned foods
# 681304                        Groceries
# 681305                        Groceries
# 681338                       Sandwiches
# 681356                        Beverages
# 681357                    Sugary snacks
# 681377                          Seafood
# 681422                       fr:Attieke
# 681424                        Beverages
# 681426                        Beverages
# 681427                        Beverages
# 681449                     Fruit juices
# 681463                        Groceries
# 681472                              NaN
# 681474  Plant-based foods and beverages
# 681491                        Beverages
# 681493                    Sugary snacks
# 681502                         Desserts
# 681514                          Spreads
# 681525                          Dairies
# 681535                        Beverages
# 681537                        pl:Szprot
# 681538                     Fruit juices
# 681585  Plant-based foods and beverages
#
#                                                 labels_en  \
# 106                                        Made in France
# 251                    fr:Viande Française,Made in France
# 254                                                   NaN
# 264                                                   NaN
# 269                                                   NaN
# 274                                                   NaN
# 285                                                   NaN
# 289                                  Kosher,Contains GMOs
# 292                                             Green Dot
# 296                                                   NaN
# 297                                                   NaN
# 299                   No artificial flavors,Contains GMOs
# 305                                                   NaN
# 346                                                   NaN
# 348                               Incorrect data on label
# 356     Not advised for specific people,PDO,Made in Fr...
# 383     Sustainable farming,UTZ Certified,UTZ Certifie...
# 405                                                   NaN
# 406                                                   NaN
# 410                                                   NaN
# 508                                                   NaN
# 516                                      Vegetarian,Vegan
# 526                                                   NaN
# 545                                                   NaN
# 564                                                   NaN
# 565                                                   NaN
# 576                                                   NaN
# 582                              Green Dot,Made in France
# 587                              Green Dot,Made in France
# 588                                                   NaN
# ...                                                   ...
# 681180                                   No preservatives
# 681193                                                NaN
# 681204  Halal,fr:Analyse-des-dangers-et-points-critiqu...
# 681235                                                NaN
# 681243  es:Peu-ou-pas-de-sucre,es:Sans-gluten,es:Sans-...
# 681253                                                NaN
# 681290  Dolphin Safe,Fished-by-pole-line,Recyclable-steel
# 681304                                         Vegetarian
# 681305                                         Vegetarian
# 681338                                   Vegetarian,Vegan
# 681356                                                NaN
# 681357                            Gluten-free,High fibres
# 681377                                                NaN
# 681422                                                NaN
# 681424                  Carbon footprint,Carbon footprint
# 681426                                                NaN
# 681427                                   Carbon footprint
# 681449                                                NaN
# 681463                                                NaN
# 681472                                                NaN
# 681474                                        Gluten-free
# 681491      Green Dot,fr:Déconseillé aux femmes enceintes
# 681493         No preservatives,fr:Fabrication artisanale
# 681502                                          Green Dot
# 681514                                                NaN
# 681525                                                PDO
# 681535                                             fr:AOC
# 681537                                                NaN
# 681538                                                NaN
# 681585                                                NaN
#
#                                          origins_tags  \
# 106                                               NaN
# 251                                            france
# 254                                            quebec
# 264                                            quebec
# 269                                            france
# 274                                            quebec
# 285                                            quebec
# 289                                               NaN
# 292                                               NaN
# 296                                            quebec
# 297                                            quebec
# 299                                               NaN
# 305                                               NaN
# 346                                     quebec,canada
# 348                                               NaN
# 356                                            france
# 383                                               NaN
# 405                                               NaN
# 406                                               NaN
# 410                                            france
# 508                                    united-kingdom
# 516                                               NaN
# 526                                               NaN
# 545                                           germany
# 564                                           germany
# 565                                           germany
# 576                                           germany
# 582                                               NaN
# 587                                               NaN
# 588                                            france
# ...                                               ...
# 681180                                            NaN
# 681193                                            NaN
# 681204                                            NaN
# 681235                                            NaN
# 681243  comunidad-valenciana,benifaio,valencia,espana
# 681253                                            NaN
# 681290                                            NaN
# 681304                                            NaN
# 681305                                            NaN
# 681338                                            NaN
# 681356                                            NaN
# 681357                                         canada
# 681377                                         norway
# 681422                                  cote-d-ivoire
# 681424                                            NaN
# 681426                                         france
# 681427                                            NaN
# 681449                                     madagascar
# 681463                                      sri-lanka
# 681472                                            NaN
# 681474                                         france
# 681491                                            NaN
# 681493                                            NaN
# 681502                                            NaN
# 681514                                france,camargue
# 681525                                       lait-cru
# 681535                              flaxieu,bugey,ain
# 681537                                         polska
# 681538                  saint-jans-cappel,nord,france
# 681585                                       inconnue
#
#                                 manufacturing_places_tags  \
# 106                                                france
# 251                                                france
# 254                                       brossard-quebec
# 264                                       brossard-quebec
# 269                                        united-kingdom
# 274                                       brossard-quebec
# 285                                       brossard,quebec
# 289                                            etats-unis
# 292                                      france,avranches
# 296                                       brossard,quebec
# 297                                       brossard-quebec
# 299                                            etats-unis
# 305                                                france
# 346                                       brossars,quebec
# 348                                              thailand
# 356                                                france
# 383                                               belgien
# 405                                        united-kingdom
# 406                                        united-kingdom
# 410                                                net-wt
# 508                                                   NaN
# 516     las-ventas-de-retamosa,toledo-provincia,castil...
# 526                                   saint-yrieix,france
# 545                                                   NaN
# 564                                               germany
# 565                                               germany
# 576                                               germany
# 582                                                france
# 587                    france,limousin,87500,saint-yrieux
# 588                                                france
# ...                                                   ...
# 681180                                           malaisie
# 681193                                           malaisie
# 681204                                           malaisie
# 681235                                                 eu
# 681243      benifaio,valencia,comunidad-valenciana,espana
# 681253                                              macao
# 681290                                              spain
# 681304                                     united-kingdom
# 681305                                     united-kingdom
# 681338                                             suisse
# 681356                                            ontario
# 681357                                                NaN
# 681377                                                NaN
# 681422                                                NaN
# 681424                      le-mouchet,drome-des-collines
# 681426  biere-brassee-au-chateau-du-mouchet-a-chavanne...
# 681427                             chavannes-26260,france
# 681449                                         madagascar
# 681463                                                NaN
# 681472                   antartic-45110-st-martin-d-abbat
# 681474                                             italie
# 681491       carib-brewery-ltd,champs-fleurs,trinidad,w-i
# 681493                                  versailles,france
# 681502                                             france
# 681514                                             france
# 681525                           moissac-vallee-francaise
# 681535                                                NaN
# 681537                                                NaN
# 681538                                                NaN
# 681585                                            hongrie
#
#        first_packaging_code_geo  \
# 106                         NaN
# 251                         NaN
# 254                         NaN
# 264                         NaN
# 269                         NaN
# 274                         NaN
# 285                         NaN
# 289                         NaN
# 292                         NaN
# 296                         NaN
# 297                         NaN
# 299                         NaN
# 305                         NaN
# 346                         NaN
# 348                         NaN
# 356                         NaN
# 383                         NaN
# 405                         NaN
# 406                         NaN
# 410                         NaN
# 508                         NaN
# 516                         NaN
# 526                         NaN
# 545                         NaN
# 564                         NaN
# 565                         NaN
# 576                         NaN
# 582                         NaN
# 587                         NaN
# 588          43.783333,0.983333
# ...                         ...
# 681180                      NaN
# 681193                      NaN
# 681204                      NaN
# 681235                      NaN
# 681243                      NaN
# 681253                      NaN
# 681290                      NaN
# 681304                      NaN
# 681305                      NaN
# 681338                      NaN
# 681356                      NaN
# 681357                      NaN
# 681377                      NaN
# 681422                      NaN
# 681424                      NaN
# 681426                      NaN
# 681427                      NaN
# 681449                      NaN
# 681463                      NaN
# 681472           47.85,2.266667
# 681474                      NaN
# 681491                      NaN
# 681493                      NaN
# 681502          46.166667,-1.15
# 681514       43.666667,4.633333
# 681525                      NaN
# 681535                      NaN
# 681537                      NaN
# 681538                      NaN
# 681585                      NaN
#
#                                              countries_en
# 106                                                France
# 251                                                France
# 254                                                Canada
# 264                                                Canada
# 269                                        United Kingdom
# 274                                                Canada
# 285                                                Canada
# 289                                  France,United States
# 292                                                France
# 296                                                Canada
# 297                                                Canada
# 299                                                France
# 305                                                France
# 346                                                Canada
# 348                                        United Kingdom
# 356                                                France
# 383                                               Germany
# 405                                        United Kingdom
# 406                                        United Kingdom
# 410                                                France
# 508                                        United Kingdom
# 516                                                 Spain
# 526                                                France
# 545                                        United Kingdom
# 564                                               Germany
# 565                                               Germany
# 576                                               Germany
# 582                                                France
# 587                                                France
# 588                                                France
# ...                                                   ...
# 681180                                             France
# 681193  Algeria,Egypt,Malaysia,Morocco,Saudi Arabia,Sy...
# 681204                                             France
# 681235                                             France
# 681243                                              Spain
# 681253                                   France,Hong Kong
# 681290                                     United Kingdom
# 681304                                     United Kingdom
# 681305                                     United Kingdom
# 681338                                        Switzerland
# 681356                                      United States
# 681357                                             Canada
# 681377                                             France
# 681422                                             France
# 681424                                             France
# 681426                                             France
# 681427                                             France
# 681449                                         Madagascar
# 681463                                             France
# 681472                                         Martinique
# 681474                                             France
# 681491                                                NaN
# 681493                                             France
# 681502                                             France
# 681514                                             France
# 681525                                             France
# 681535                                             France
# 681537                                             Poland
# 681538                                             France
# 681585                                             France
#
# [80282 rows x 7 columns]

# %% [markdown]
# ## Destination
# Split so that there is only 1 country remaining in "countries_en"

# %%
z = data_loc["countries_en"].str.split(',').apply(pd.Series)

# %%
z1 = z.unstack().dropna()

# %%
z1 = z1.to_frame()
z1.columns = ['destination']

# %%
z1.head()
# Out:
#           destination
# 0 106          France
#   251          France
#   254          Canada
#   264          Canada
#   269  United Kingdom

# %%
# change destination with special characters
# manually checked on wikipedia + google maps
z1[z1['destination'] == 'Other-日本'] = 'Japon' # manually checked on wiki
z1[z1['destination'] == '中国'] = 'Chine'
z1[z1['destination'] == 'fr:香港'] = 'Hong Kong'
z1[z1['destination'] == 'fr:日本'] = 'Japon'
z1[z1['destination'] == 'Ελλάδα'] = 'Grèce'
z1[z1['destination'] == 'ar:صنعاء'] = 'Sanaa'
z1[z1['destination'] == 'fr:الجزائر'] = 'Algérie'

# %%
# remove fr: or others xx: in destination

def split_xx(l):
    tmp = l.split(':')
    
    if len(tmp) == 1:
        return l
    else:
        return tmp[1]
        
z1['destination'] = z1['destination'].apply(lambda l: split_xx(l))

# %%
print(z1.shape)
z1 = z1[~(z1 == 'Photos uploaded')]
z1 = z1[~(z1 == 'Photos validated')]
z1 = z1[~(z1 == 'Product name completed')]
z1 = z1[~(z1 == 'Photos to be uploaded')]
z1 = z1[~(z1 == 'Photos to be validated')]
z1 = z1[~(z1 == 'Quantity completed')]
z1 = z1[~(z1 == 'Nutrition facts completed')]
z1 = z1[~(z1 == 'Ingredients completed')]
z1 = z1[~(z1 == 'Brands completed')]
z1 = z1[~(z1 == 'Packaging completed')]
z1 = z1[~(z1 == 'Characteristics completed')]
z1 = z1[~(z1 == 'Categories completed')]
z1 = z1[~(z1 == 'Packaging-code-completed')]
z1 = z1[~(z1 == 'Expiration date completed')]
z1 = z1[~(z1 == 'Expiration date to be completed')]
z1 = z1[~(z1 == 'En')]
z1 = z1[~(z1 == 'To be completed')]
z1 = z1[~(z1 == 'To be checked')]
z1 = z1[~(z1 == 'Worldwide')]
z1 = z1[~(z1 == 'World')]
z1 = z1[~(z1 == 'Sucre')]
z1 = z1[~(z1 == 'Complete')]
z1 = z1[~(z1 == 'Global-market')]
z1 = z1[~(z1 == 'Dat')]
z1 = z1[~(z1 == 'France-others')]

z1 = z1.dropna()
print(z1.shape)
#z1 = z1.to_frame()
# Out:
# (89510, 1)
# (88959, 1)

# %%
# replace values manually
z1[z1['destination'] == 'Leclerc-bois-d-arcy-france'] = 'France'
z1[z1['destination'] == 'Francecontient-des-sulfites'] = 'France'
z1[z1['destination'] == 'Leclerc'] = 'France'
z1[z1['destination'] == 'Auchan'] = 'France'
z1[z1['destination'] == 'Carrefour'] = 'France'
z1[z1['destination'] == 'Estadps-unidos'] = 'United States'
z1[z1['destination'] == 'Polyensie-francaise'] = 'French Polynesia'

# %%
z1['destination'].unique().shape
# Out:
# (238,)

# %%
z1['destination'].unique()
# Out:
# array(['France', 'Canada', 'United Kingdom', 'Germany', 'Spain',
#        'United States', 'Belgium', 'Australia', 'Egypt', 'Haiti',
#        'Mexico', 'Italy', 'Switzerland', 'Saudi Arabia', 'Greece',
#        'Netherlands', 'Jordan', 'Hong Kong', 'Denmark',
#        'French Polynesia', 'European Union', 'Serbia', 'New Caledonia',
#        'United Arab Emirates', 'Cuba', 'Argentina', 'Mauritius',
#        'Morocco', 'Sweden', 'Thailand', 'China',
#        'Saint Pierre and Miquelon', 'Quebec', 'Czech Republic', 'Austria',
#        'India', 'Turkey', 'Cambodia', 'Portugal', 'Colombia', 'Réunion',
#        'Burkina Faso', 'Algeria', 'Russia', 'Oman', 'Brazil',
#        'Costa Rica', 'Romania', 'Democratic Republic of the Congo',
#        'Cyprus', 'Japan', 'Cameroon', 'Lebanon', 'Philippines', 'Ecuador',
#        'South Africa', 'Israel', 'Chile', 'Taiwan', 'Dominica', 'Myanmar',
#        'Peru', 'Indonesia', 'Finland', 'Poland', 'Lithuania', 'Ireland',
#        'Senegal', "Côte d'Ivoire", 'Togo', 'Iceland', 'South Korea',
#        'Tunisia', 'Iraq', 'Guadeloupe', 'Madagascar', 'Bulgaria',
#        'Hungary', 'Ukraine', 'French Guiana', 'Allemagne', 'Scotland',
#        'Deutschland', 'Croatia', 'Vietnam', 'Slovenia', 'Benin',
#        'Luxembourg', 'Gabon', 'Dom-tom', 'Mauritania', 'Libya',
#        'Martinique', 'Mayotte', 'Guinea', 'Andorra', 'Pakistan',
#        'Estonia', 'Saint Martin', 'Europe', 'Bosnia and Herzegovina',
#        'Montenegro', 'Albania', 'Suisse', 'Armenia', 'Belarus',
#        'Frankreich', 'Slovakia', 'Latvia', 'Moldova', 'Georgia', 'Japon',
#        'Rwanda', 'Singapore', 'Malaysia', 'Republic of Macedonia',
#        'Malta', 'Espagne', 'Azerbaijan', 'Mali', 'Yemen', 'Algerie',
#        'Kenya', 'Tanzania', 'Republic of the Congo', 'Iran', 'Kuwait',
#        'Qatar', 'Chine', 'Norway', 'El Salvador', 'Honduras', 'Guatemala',
#        'Venezuela', 'Paraguay', 'Frankrijk', 'Catalunya', 'Niger',
#        'New Zealand', 'Tunisie', 'Kuala-lumpur', 'Namibia', 'Fiji',
#        'Sarlat', 'Polynesie-francaise', 'Montserrat', 'Toulouse',
#        'Ile-de-la-reunion', 'Virgin Islands of the United States',
#        'Cognac-france', 'Quebec-canada', 'Suiss', 'Soviet Union', 'Macau',
#        'Grece', 'Nancy', 'Belgique', 'Sint Maarten', 'Monaco', 'Vanuatu',
#        'Belgie', 'Marnay-70150', 'Draveil', 'Nyons', 'Antilles', 'Marly',
#        'Aveyron', 'Dominican Republic', 'Occitanie', 'Tahiti', 'Apt',
#        'France-outre-mer', 'Kazakhstan', 'Niort', 'Kosovo', 'Benelux',
#        'Schweiz', 'Uruguay', 'Sri Lanka', 'Grande-bretagne-uk',
#        'Nederland', 'Grèce', 'Danemark', 'Swaziland', 'Alemanha',
#        'Espanha', 'Sanaa', 'Malawi', 'Algérie',
#        'Central African Republic', 'Sverige', 'Dubai', 'Suisse-valais',
#        'Liechtenstein', 'Cee', 'Belgien', 'Pays-bas', 'Alemania',
#        'Hungria', 'Suiza', 'Frankrike', 'England', 'Franca', 'Chad',
#        'Syria', 'Svizzera', 'Estados-unidos', 'Duitsland', 'Spanien',
#        'Moorea', 'Reino-unido', 'Nederlanderna', 'Tschechien',
#        'Danemarca', 'Serbie', 'Equatorial Guinea', 'Hongrie', 'Australie',
#        'Paises-bajos', 'Suriname', 'Vereinigtes-konigreich', 'Elveția',
#        'Royaume-uni', 'Irlande', 'Russie', 'Niederlande', 'Tyskland',
#        'Franța', 'Dinamarca', 'Maldives', 'Spanje', 'Muntenegru',
#        'Slovenie', 'Marruecos', 'Verenigd-koninkrijk', 'Suede',
#        'Republika Srpska', 'Ungaria'], dtype=object)

# %% [markdown]
# Several countries are represented twice (or more) with the name of the country in different languages. ex. Greece and Grèce are the same country. Thus the count of the product for both shoud be added.

# %%
z1["destination"].value_counts().shape
# Out:
# (238,)

# %%
country_count = z1["destination"].value_counts()[0:20]

sns.set(style="whitegrid")
sns.barplot(y=country_count.index, x=country_count.values)

# %%
country_count = z1["destination"].value_counts()[1:25]

sns.set(style="whitegrid")
sns.barplot(y=country_count.index, x=country_count.values)

# %% [markdown]
# ## Make a dico to have unique countries ==> find country name in english

# %%
dico = pd.read_csv('data/Destination-Coordinate-MAN.csv',delimiter=',',low_memory=False)
dico.head()
# Out:
#    Unnamed: 0    Unnamed: 0.1     destination         country
# 0           0          France          France          France
# 1           1           Spain           Spain           Spain
# 2           2         Germany         Germany         Germany
# 3           3     Switzerland     Switzerland     Switzerland
# 4           4  United Kingdom  United Kingdom  United Kingdom

# %%
dictionary_country = dict(zip(dico['destination'], dico['country']))
dictionary_country
# Out:
# {'France': 'France',
#  'Spain': 'Spain',
#  'Germany': 'Germany',
#  'Switzerland': 'Switzerland',
#  'United Kingdom': 'United Kingdom',
#  'Belgium': 'Belgium',
#  'Mexico': 'Mexico',
#  'Australia': 'Australia',
#  'United States': 'USA',
#  'Italy': 'Italy',
#  'Sweden': 'Sweden',
#  'Canada': 'Canada',
#  'Serbia': 'Serbia',
#  'Portugal': 'Portugal',
#  'Russia': 'Russia',
#  'Romania': 'Romania',
#  'Netherlands': 'Netherlands',
#  'Austria': 'Austria',
#  'Denmark': 'Denmark',
#  'Réunion': 'France',
#  'Hungary': 'Hungary',
#  'Guadeloupe': 'France',
#  'Brazil': 'Brazil',
#  'French Polynesia': 'France',
#  'Hong Kong': 'Hong Kong',
#  'Poland': 'Poland',
#  'Madagascar': 'Madagascar',
#  'Ireland': 'Ireland',
#  'Tunisia': 'Tunisia',
#  'New Zealand': 'New Zealand',
#  'India': 'India',
#  'South Africa': 'RSA',
#  'Luxembourg': 'Luxembourg',
#  'French Guiana': 'France',
#  'Georgia': 'USA',
#  'Deutschland': 'Germany',
#  'Czech Republic': 'Czechia',
#  'Morocco': 'Morocco',
#  'Algeria': 'Algeria',
#  'Martinique': 'France',
#  'Greece': 'Greece',
#  'Bulgaria': 'Bulgaria',
#  'Finland': 'Finland',
#  'Allemagne': 'Germany',
#  'Taiwan': 'ROC',
#  'Argentina': 'Argentina',
#  'New Caledonia': 'France',
#  'Mauritius': 'Mauritius',
#  'Thailand': 'Thailand',
#  'Norway': 'Norway',
#  'Turkey': 'Turkey',
#  'Senegal': 'Senegal',
#  'Montenegro': 'Montenegro',
#  'Japan': 'Japan',
#  'Croatia': 'Croatia',
#  'China': 'PRC',
#  'Saint Pierre and Miquelon': 'France',
#  'Slovenia': 'Slovenia',
#  'Suisse': 'Switzerland',
#  'Israel': 'Israel',
#  'Chile': 'Chile',
#  'Slovakia': 'Slovakia',
#  'United Arab Emirates': 'United Arab Emirates',
#  'Cambodia': 'Cambodia',
#  'Colombia': 'Colombia',
#  'Bosnia and Herzegovina': 'B&H',
#  'Quebec': 'Canada',
#  'Cameroon': 'Cameroon',
#  'Singapore': 'Singapore',
#  'Indonesia': 'Indonesia',
#  'Albania': 'Albania',
#  'Frankreich': 'France',
#  'Egypt': 'Egypt',
#  'Republic of Macedonia': 'Macedonia',
#  'Saudi Arabia': 'Saudi Arabia',
#  'Malta': 'Malta',
#  'Belgique': 'Belgium',
#  'Lebanon': 'Lebanon',
#  'Estonia': 'Estonia',
#  'Andorra': 'Andorra',
#  'Espagne': 'Spain',
#  'Azerbaijan': 'Azerbaijan',
#  'Iraq': 'Iraq',
#  "Côte d'Ivoire": "Côte d'Ivoire",
#  'Cuba': 'Cuba',
#  'Iceland': 'Iceland',
#  'Philippines': 'Philippines',
#  'Peru': 'Peru',
#  'Burkina Faso': 'Burkina Faso',
#  'Scotland': 'United Kingdom',
#  'South Korea': 'South Korea',
#  'Ukraine': 'Ukraine',
#  'Schweiz': 'Switzerland',
#  'Alemania': 'Germany',
#  'European Union': 'Europe',
#  'Latvia': 'Latvia',
#  'Costa Rica': 'Costa Rica',
#  'Lithuania': 'Lithuania',
#  'Jordan': 'Jordan',
#  'Republic of the Congo': 'Congo',
#  'Dom-tom': 'France',
#  'Vietnam': 'Vietnam',
#  'Belgie': 'Belgium',
#  'Gabon': 'Gabon',
#  'Armenia': 'Armenia',
#  'Yemen': 'Yemen',
#  'Democratic Republic of the Congo': 'Congo',
#  'Europe': 'Europe',
#  'Qatar': 'Qatar',
#  'Monaco': 'Monaco',
#  'Malaysia': 'Malaysia',
#  'Libya': 'Libya',
#  'Suiza': 'Switzerland',
#  'Moldova': 'Moldova',
#  'Uruguay': 'Uruguay',
#  'Mali': 'Mali',
#  'Kuwait': 'Kuwait',
#  'Sverige': 'Sweden',
#  'Algérie': 'Algeria',
#  'Swaziland': 'Swaziland',
#  'Kazakhstan': 'Kazakhstan',
#  'Pays-bas': 'Netherlands',
#  'Oman': 'Oman',
#  'Royaume-uni': 'United Kingdom',
#  'Espanha': 'Spain',
#  'Kenya': 'Kenya',
#  'Reino-unido': 'United Kingdom',
#  'Sanaa': 'Yemen',
#  'Frankrijk': 'France',
#  'Togo': 'Togo',
#  'Ecuador': 'Ecuador',
#  'Danemark': 'Denmark',
#  'Sint Maarten': 'Netherlands',
#  'Serbie': 'Serbia',
#  'Cyprus': 'Cyprus',
#  'Japon': 'Japan',
#  'Pakistan': 'Pakistan',
#  'Chine': 'PRC',
#  'Nederland': 'Netherlands',
#  'Polynesie-francaise': 'France',
#  'Soviet Union': 'Ukraine',
#  'Catalunya': 'Spain',
#  'Rwanda': 'Rwanda',
#  'Cee': 'Spain',
#  'Tahiti': 'Polynésie française (eaux territoriales)',
#  'Mayotte': 'France',
#  'Iran': 'Iran',
#  'Sri Lanka': 'Sri Lanka',
#  'Vereinigtes-konigreich': 'United Kingdom',
#  'Franca': 'France',
#  'Grece': 'Greece',
#  'Spanien': 'Spain',
#  'Syria': 'Syria',
#  'Australie': 'Australia',
#  'Niger': 'Niger',
#  'Belarus': 'Belarus',
#  'Draveil': 'France',
#  'Benin': 'Benin',
#  'Irlande': 'Ireland',
#  'Equatorial Guinea': 'Equatorial Guinea',
#  'Marly': 'France',
#  'Sarlat': 'France',
#  'Quebec-canada': 'Canada',
#  'Cognac-france': 'France',
#  'Guatemala': 'Guatemala',
#  'Slovenie': 'Slovenia',
#  'Suisse-valais': 'Switzerland',
#  'Namibia': 'Namibia',
#  'England': 'United Kingdom',
#  'Tunisie': 'Tunisia',
#  'Niort': 'France',
#  'Grande-bretagne-uk': 'United Kingdom',
#  'Muntenegru': 'Montenegro',
#  'Nyons': 'France',
#  'Apt': 'France',
#  'Russie': 'Russia',
#  'Aveyron': 'France',
#  'Dominican Republic': 'Dominica',
#  'Spanje': 'Spain',
#  'Fiji': 'Fiji',
#  'Marruecos': 'Morocco',
#  'Suiss': 'Switzerland',
#  'Liechtenstein': 'Liechtenstein',
#  'Paraguay': 'Paraguay',
#  'Franța': 'France',
#  'Marnay-70150': 'France',
#  'Ungaria': 'Hungary',
#  'Kuala-lumpur': 'Malaysia',
#  'Belgien': 'Belgium',
#  'Virgin Islands of the United States': 'USA',
#  'Nederlanderna': 'Netherlands',
#  'Dinamarca': 'Denmark',
#  'Alemanha': 'Germany',
#  'Algerie': 'Algeria',
#  'Benelux': 'Belgium',
#  'Republika Srpska': 'B&H',
#  'Ile-de-la-reunion': 'France',
#  'Hungria': 'Hungary',
#  'El Salvador': 'El Salvador',
#  'Chad': 'Chad',
#  'Antilles': 'USA',
#  'Honduras': 'Honduras',
#  'Maldives': 'Maldives',
#  'Dominica': 'Dominica',
#  'Svizzera': 'Switzerland',
#  'Suede': 'Sweden',
#  'Estados-unidos': 'USA',
#  'Occitanie': 'France',
#  'Tanzania': 'Tanzania',
#  'Frankrike': 'France',
#  'Elveția': 'Switzerland',
#  'Montserrat': 'Montserrat',
#  'Malawi': 'Malawi',
#  'Myanmar': 'Myanmar',
#  'Venezuela': 'Venezuela',
#  'Toulouse': 'France',
#  'Dubai': 'United Arab Emirates',
#  'France-outre-mer': 'France',
#  'Danemarca': 'Denmark',
#  'Duitsland': 'Germany',
#  'Nancy': 'France',
#  'Tyskland': 'Germany',
#  'Hongrie': 'Hungary',
#  'Niederlande': 'Netherlands',
#  'Central African Republic': 'CAR',
#  'Suriname': 'Suriname',
#  'Saint Martin': 'France',
#  'Vanuatu': 'Vanuatu',
#  'Mauritania': 'Mauritania',
#  'Grèce': 'Greece',
#  'Haiti': 'Haiti',
#  'Kosovo': 'Kosovo',
#  'Paises-bajos': 'Netherlands',
#  'Guinea': 'Guinea',
#  'Tschechien': 'Czechia',
#  'Verenigd-koninkrijk': 'United Kingdom',
#  'Macau': 'Macau',
#  'Moorea': 'Polynésie française (eaux territoriales)'}

# %% [markdown]
# ## Apply to the products

# %%
z1_safe = z1
z1.head()
# Out:
#           destination
# 0 106          France
#   251          France
#   254          Canada
#   264          Canada
#   269  United Kingdom

# %%
z1.shape
# Out:
# (96837, 2)

# %%
z1.head()
# Out:
#           destination
# 0 106          France
#   251          France
#   254          Canada
#   264          Canada
#   269  United Kingdom

# %%
# test
dictionary_country['Verenigd-koninkrijk']
# Out:
# 'United Kingdom'

# %%
z1['Arrival'] = z1['destination'].apply(lambda l: dictionary_country[l])

# %%
print(z1['Arrival'].shape)
z1 = z1[z1['Arrival'] != 'NaN']
print(z1['Arrival'].shape)
# Out:
# (88959,)
# (88959,)

# %%
count = z1['Arrival'].value_counts()

# %%
z1["Arrival"].value_counts().shape
# Out:
# (134,)

# %%
country_count = z1["Arrival"].value_counts()[0:25]

sns.set(style="whitegrid")
sns.barplot(y=country_count.index, x=country_count.values)

# %%
country_count = z1["Arrival"].value_counts()[1:25]

sns.set(style="whitegrid")
sns.barplot(y=country_count.index, x=country_count.values)
