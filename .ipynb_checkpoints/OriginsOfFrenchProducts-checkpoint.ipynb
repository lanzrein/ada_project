# %%
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopy as gp
from geopy import distance

# %% [markdown]
# # Learning a few tricks with network X as warm up

# %%
graph = nx.star_graph(10)
graph = graph.to_directed()
nx.draw(graph,with_labels=True)
plt.show()

# %%
# graph.remove_edge(0,1)
# nx.draw(graph,with_labels=True)
# plt.show()

# %%
xs = ["France","Italy","Switzerland","Germany","Denmark","UK","Sweden","Finland","Thailand","USA","Japan"]
mapping = dict(zip(range(len(xs)),xs))
test = nx.relabel_nodes(graph,mapping)
nx.draw(test,with_labels=True,node_size=2500,arrowstyle='->')
plt.show()

# %%
nx.draw(test,nx.spring_layout(test),with_labels=True)
nx.draw_networkx_edge_labels(test,nx.spring_layout(test))


plt.show()

# %%
g = nx.DiGraph()
i = 1
g.add_star(mapping.values(),weight=3,length=i)

edge_labels=dict([((u,v,),d['weight'])
             for u,v,d in g.edges(data=True)])
# nx.draw_networkx_edge_labels(g,pos=nx.spring_layout(g),edge_labels=edge_labels)
nx.draw(g,pos=nx.spring_layout(g),with_labels=True)
plt.show()

# %%
import matplotlib as mpl
node_sizes = [250*i+250 for i in range(len(g))]
node_sizes
edge_colors=range(2,g.number_of_edges()+2)
edge_alphas = [(5+i)/(g.number_of_edges() +4) for i in range(g.number_of_edges())]
pos = nx.layout.spring_layout(g)
nodes = nx.draw_networkx_nodes(g,pos,node_size=node_sizes,node_color='yellow')
labels = nx.draw_networkx_labels(g,pos,labels=mapping)
edges = nx.draw_networkx_edges(g,pos,node_size=node_sizes,arrowstyle='->',arrowsize=10,width = 2,edge_cmap = plt.cm.Blues,edge_color=edge_colors)

# set an alpha
# for i in range(g.number_of_edges()):
#     edges[i].set_alpha(edge_alphas[i])
pc = mpl.collections.PatchCollection(edges,cmap=plt.cm.Blues)
pc.set_array(edge_colors)
plt.colorbar(pc)
ax = plt.gca()
ax.set_axis_off()
fig = plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %%
g.nodes
# Out:
# NodeView(('France', 'Italy', 'Switzerland', 'Germany', 'Denmark', 'UK', 'Sweden', 'Finland', 'Thailand', 'USA', 'Japan'))

# %% [markdown]
# # Food origin network graphs

# %%
food_origins = pd.read_csv('data/food_origins.csv')
food_origins.set_index('code')
# Out:
#                                  origins_tags                 origins_tags.1  \
# code
# 0000000020114                             NaN                            NaN
# 0000000274722                          france                         france
# 0000000290616                          quebec                         quebec
# 0000000394710                          quebec                         quebec
# 0000001071894                          france                         france
# 0000001938067                          quebec                         quebec
# 0000004302544                          quebec                         quebec
# 0000007020254                             NaN                            NaN
# 0000007730009                             NaN                            NaN
# 0000008237798                          quebec                         quebec
# 0000008240095                          quebec                         quebec
# 0000009336247                             NaN                            NaN
# 0000010090206                             NaN                            NaN
# 0000012167005                   quebec,canada                  quebec,canada
# 0000012345878                             NaN                            NaN
# 0000020004552                          france                         france
# 0000020424640                             NaN                            NaN
# 0000027533024                             NaN                            NaN
# 0000027533048                             NaN                            NaN
# 0000034152010                          france                         france
# 00000758                       united-kingdom                 united-kingdom
# 0000084154071                             NaN                            NaN
# 000010                                    NaN                            NaN
# 00001373                              germany                        germany
# 0000204286484                         germany                        germany
# 0000204286644                         germany                        germany
# 0000250632969                         germany                        germany
# 000030                                    NaN                            NaN
# 000031                                    NaN                            NaN
# 00003100                               france                         france
# ...                                       ...                            ...
# 9588800664918                             NaN                            NaN
# 96069868                                  NaN                            NaN
# 96092514                                  NaN                            NaN
# 96092521                                  NaN                            NaN
# 9614237120878                             NaN                            NaN
# 9661975680                                NaN                            NaN
# 9661981813                             canada                         canada
# 9700467750708                             NaN                            NaN
# 97055722040915                         norway                         norway
# 9780201379129                   cote-d-ivoire                  cote-d-ivoire
# 9780221379642                             NaN                            NaN
# 9780545789646                          france                         france
# 9780546379648                             NaN                            NaN
# 9782266216722                         tunisie                        tunisie
# 9782914717502                      madagascar                     madagascar
# 9791463741241                       sri-lanka                      sri-lanka
# 98131846                                  NaN                            NaN
# 98152056                               france                         france
# 9871311007                                NaN                            NaN
# 9876754344551                             NaN                            NaN
# 9900000001926                             NaN                            NaN
# 9900000002237                             NaN                            NaN
# 9900010011557                 france,camargue                france,camargue
# 99020118                             lait-cru                       lait-cru
# 9906410000009               flaxieu,bugey,ain              flaxieu,bugey,ain
# 9908278636246                          polska                         polska
# 9909206000009   saint-jans-cappel,nord,france  saint-jans-cappel,nord,france
# 9991111111154                             NaN                            NaN
# 9996980313319                        inconnue                       inconnue
# 9999900002553                             NaN                            NaN
#
#                                         manufacturing_places_tags
# code
# 0000000020114                                              france
# 0000000274722                                              france
# 0000000290616                                     brossard-quebec
# 0000000394710                                     brossard-quebec
# 0000001071894                                      united-kingdom
# 0000001938067                                     brossard-quebec
# 0000004302544                                     brossard,quebec
# 0000007020254                                          etats-unis
# 0000007730009                                    france,avranches
# 0000008237798                                     brossard,quebec
# 0000008240095                                     brossard-quebec
# 0000009336247                                          etats-unis
# 0000010090206                                              france
# 0000012167005                                     brossars,quebec
# 0000012345878                                            thailand
# 0000020004552                                              france
# 0000020424640                                             belgien
# 0000027533024                                      united-kingdom
# 0000027533048                                      united-kingdom
# 0000034152010                                              net-wt
# 00000758                                                      NaN
# 0000084154071   las-ventas-de-retamosa,toledo-provincia,castil...
# 000010                                        saint-yrieix,france
# 00001373                                                      NaN
# 0000204286484                                             germany
# 0000204286644                                             germany
# 0000250632969                                             germany
# 000030                                                     france
# 000031                         france,limousin,87500,saint-yrieux
# 00003100                                                   france
# ...                                                           ...
# 9588800664918                                               macao
# 96069868                                                    spain
# 96092514                                           united-kingdom
# 96092521                                           united-kingdom
# 9614237120878                                              suisse
# 9661975680                                                ontario
# 9661981813                                                    NaN
# 9700467750708                                                 NaN
# 97055722040915                                                NaN
# 9780201379129                                                 NaN
# 9780221379642                       le-mouchet,drome-des-collines
# 9780545789646   biere-brassee-au-chateau-du-mouchet-a-chavanne...
# 9780546379648                              chavannes-26260,france
# 9782266216722                                                 NaN
# 9782914717502                                          madagascar
# 9791463741241                                                 NaN
# 98131846                         antartic-45110-st-martin-d-abbat
# 98152056                                                   italie
# 9871311007           carib-brewery-ltd,champs-fleurs,trinidad,w-i
# 9876754344551                                   versailles,france
# 9900000001926                                              france
# 9900000002237                                                 NaN
# 9900010011557                                              france
# 99020118                                 moissac-vallee-francaise
# 9906410000009                                                 NaN
# 9908278636246                                                 NaN
# 9909206000009                                                 NaN
# 9991111111154                                                 NaN
# 9996980313319                                             hongrie
# 9999900002553                                                 NaN
#
# [86142 rows x 3 columns]

# %%
data = pd.read_csv('data/cleaned_unique_index.csv',low_memory=False)
data.set_index('code',inplace=True)
data.head()
# Out:
#                                                              url   creator  \
# code
# 0000000000017  http://world-en.openfoodfacts.org/product/0000...   kiliweb
# 0000000000031  http://world-en.openfoodfacts.org/product/0000...  isagoofy
# 0000000000123  http://world-en.openfoodfacts.org/product/0000...   kiliweb
# 0000000000291  http://world-en.openfoodfacts.org/product/0000...   kiliweb
# 0000000000949  http://world-en.openfoodfacts.org/product/0000...   kiliweb
#
#                 created_t      created_datetime last_modified_t  \
# code
# 0000000000017  1529059080  2018-06-15T10:38:00Z      1529059204
# 0000000000031  1539464774  2018-10-13T21:06:14Z      1539464817
# 0000000000123  1535737982  2018-08-31T17:53:02Z      1535737986
# 0000000000291  1534239669  2018-08-14T09:41:09Z      1534239732
# 0000000000949  1523440813  2018-04-11T10:00:13Z      1523440823
#
#               last_modified_datetime               product_name generic_name  \
# code
# 0000000000017   2018-06-15T10:40:04Z           Vitória crackers          NaN
# 0000000000031   2018-10-13T21:06:57Z                      Cacao          NaN
# 0000000000123   2018-08-31T17:53:06Z      Sauce Sweety chili 0%          NaN
# 0000000000291   2018-08-14T09:42:12Z                  Mendiants          NaN
# 0000000000949   2018-04-11T10:00:23Z  Salade de carottes râpées          NaN
#
#               quantity packaging      ...       carbon-footprint_100g  \
# code                                  ...
# 0000000000017      NaN       NaN      ...                         NaN
# 0000000000031    130 g       NaN      ...                         NaN
# 0000000000123      NaN       NaN      ...                         NaN
# 0000000000291      NaN       NaN      ...                         NaN
# 0000000000949      NaN       NaN      ...                         NaN
#
#               nutrition-score-fr_100g nutrition-score-uk_100g  \
# code
# 0000000000017                     NaN                     NaN
# 0000000000031                     NaN                     NaN
# 0000000000123                     NaN                     NaN
# 0000000000291                     NaN                     NaN
# 0000000000949                     NaN                     NaN
#
#               glycemic-index_100g water-hardness_100g choline_100g  \
# code
# 0000000000017                 NaN                 NaN          NaN
# 0000000000031                 NaN                 NaN          NaN
# 0000000000123                 NaN                 NaN          NaN
# 0000000000291                 NaN                 NaN          NaN
# 0000000000949                 NaN                 NaN          NaN
#
#               phylloquinone_100g beta-glucan_100g inositol_100g carnitine_100g
# code
# 0000000000017                NaN              NaN           NaN            NaN
# 0000000000031                NaN              NaN           NaN            NaN
# 0000000000123                NaN              NaN           NaN            NaN
# 0000000000291                NaN              NaN           NaN            NaN
# 0000000000949                NaN              NaN           NaN            NaN
#
# [5 rows x 173 columns]

# %%
origins_france = data['France' == data['countries_en']][['origins_tags']]
origins_france.head()
# Out:
#               origins_tags
# code
# 0000000000017          NaN
# 0000000000031          NaN
# 0000000000123          NaN
# 0000000000291          NaN
# 0000000000949          NaN

# %%
origins_france = origins_france.dropna()

# %%
z = origins_france["origins_tags"].str.split(',').apply(pd.Series).unstack().dropna().to_frame()
z = z.reset_index().set_index('code')
z.columns = ['','origins_tags']
origins_split = z[['origins_tags']]

# %%
grouped = origins_split['origins_tags'].value_counts().to_frame()
grouped.columns=['count']
exclude = ['provence','agriculture-ue','ue','lait-origine-france','sud-ouest','hors-france','normandie','hors-union-europeenne','agriculture-ue-non-ue','union-europeenne','bretagne']
for e in exclude : 
    grouped = grouped[grouped.index != e]
top15 = grouped.nlargest(15,'count')
top15
# Out:
#                  count
# france           14721
# espagne           1052
# italie            1033
# perou              343
# norvege            286
# allemagne          251
# chine              222
# thailande          218
# belgique           203
# maroc              196
# turquie            188
# equateur           184
# pays-bas           177
# ecosse             165
# ocean-pacifique    150

# %%
import matplotlib as mpl
import math
labs = ['']+list(top15.index)
labs = dict(zip(labs,labs))
g = nx.DiGraph()
i = 1
g.add_star(['']+list(top15.index))

node_sizes = [250*i+250 for i in range(len(g))]
node_sizes
edge_colors=range(2,g.number_of_edges()+2 )
edge_colors =list(map(math.log,top15.values.ravel()))
edge_alphas = [(5+i)/(g.number_of_edges() +4) for i in range(g.number_of_edges())]
pos = nx.layout.spring_layout(g)
nodes = nx.draw_networkx_nodes(g,pos,node_size=300,node_color='#ADD8E6')
labels = nx.draw_networkx_labels(g,pos,labels=labs)
edges = nx.draw_networkx_edges(g,pos,arrowstyle='->',arrowsize=10,width = 2,edge_cmap = plt.cm.winter,edge_color=edge_colors)


pc = mpl.collections.PatchCollection(edges,cmap=plt.cm.winter)
pc.set_array(edge_colors)
plt.colorbar(pc)
ax = plt.gca()
ax.set_axis_off()
fig = plt.gcf()
fig.set_size_inches(12,8)
plt.title("Importation of product to france by count. Log scale is used")
plt.show()

# %%
top15.plot.bar(logy=True)

# %%
import matplotlib as mpl
labs = ['']+list(top15.index)
labs = dict(zip(labs,labs))
g = nx.DiGraph()
i = 1
g.add_star(['']+list(top15.index))

node_sizes = [100]+list(top15.values.ravel())
# edge_colors=range(2,g.number_of_edges()+2 )
# edge_colors =list(map(math.log,top15.values.ravel()))
# edge_alphas = [(5+i)/(g.number_of_edges() +4) for i in range(g.number_of_edges())]
pos = nx.layout.spring_layout(g)
nodes = nx.draw_networkx_nodes(g,pos,node_size=node_sizes,node_color='#ADD8E6')
labels = nx.draw_networkx_labels(g,pos,labels=labs)
edges = nx.draw_networkx_edges(g,pos,node_size=node_sizes,arrowstyle='->',arrowsize=10,width = 2)#,edge_cmap = plt.cm.winter,edge_color=edge_colors)


# pc = mpl.collections.PatchCollection(edges,cmap=plt.cm.winter)
# pc.set_array(edge_colors)
# plt.colorbar(pc)
ax = plt.gca()
ax.set_axis_off()
fig = plt.gcf()
fig.set_size_inches(14,10)
plt.title("Importation of product to france by count.")
plt.show()

# %%
z = origins_france.join(data,lsuffix='l',rsuffix='r')

# %%
z = z[["categories_en"]]
z = z["categories_en"].str.split(',').apply(pd.Series).unstack().dropna().to_frame()
z = z.reset_index().set_index('code')
z.columns = ['','categories_en']
categories_split = z[['categories_en']]

# %%
by_cat_france = categories_split["categories_en"].value_counts().to_frame()
by_cat_15 = by_cat_france.nlargest(15,'categories_en')
by_cat_15.plot.barh()

# %%
import matplotlib as mpl
labs = ['']+list(by_cat_15.index)
labs = dict(zip(labs,labs))
g = nx.DiGraph()
i = 1
g.add_star(['']+list(by_cat_15.index))

node_sizes = [100]+list(by_cat_15.values.ravel())
# edge_colors=range(2,g.number_of_edges()+2 )
edge_colors =np.random.randint(10,100,g.number_of_edges())
# edge_alphas = [(5+i)/(g.number_of_edges() +4) for i in range(g.number_of_edges())]
pos = nx.layout.spring_layout(g)
nodes = nx.draw_networkx_nodes(g,pos,node_size=node_sizes,node_color='pink')
labels = nx.draw_networkx_labels(g,pos,labels=labs,font_color='yellow')
edges = nx.draw_networkx_edges(g,pos,node_size=node_sizes,arrowstyle='->',arrowsize=10,width = 2,edge_cmap = plt.cm.winter,edge_color=edge_colors)


pc = mpl.collections.PatchCollection(edges,cmap=plt.cm.winter)
# pc.set_array(edge_colors)
# plt.colorbar(pc)
ax = plt.gca()
ax.set_axis_off()
fig = plt.gcf()
fig.patch.set_facecolor('y')
fig.set_size_inches(14,10)
plt.title("Categories of product to france by count.",color='yellow')
plt.show()

# %%
by_cat_15.plot.pie('categories_en',labels=None,figsize=(14,14))
plt.title("All graphs are beautiful even me")
plt.show()

# %%
## For each main categories do a cutie network graph like above to see if we have any trends :) 
for cat in by_cat_15.index:
    print("------")

    print(cat)
    cat_pd = categories_split[cat ==  categories_split["categories_en"]]
    origin_cat = cat_pd.join(origins_split)
    top10 = origin_cat["origins_tags"].value_counts().to_frame().nlargest(10,"origins_tags")
    do_star_graph_series(top10,mode='node')
    print("-----------")
# Out:
# ------
# Plant-based foods and beverages
# -----------
# ------
# Plant-based foods
# -----------
# ------
# Meats
# -----------
# ------
# Dairies
# -----------
# ------
# Fruits and vegetables based foods
# -----------
# ------
# Meals
# -----------
# ------
# Prepared meats
# -----------
# ------
# Beverages
# -----------
# ------
# Fermented milk products
# -----------
# ------
# Fermented foods
# -----------
# ------
# Fresh foods
# -----------
# ------
# Cereals and potatoes
# -----------
# ------
# Spreads
# -----------
# ------
# Frozen foods
# -----------
# ------
# Cheeses
# -----------

# %%
def do_star_graph_series(series,node_color='pink',font_color='black',mode='node'):
    labs = ['']+list(series.index)
    labs = dict(zip(labs,labs))
    g = nx.DiGraph()
    i = 1
    g.add_star(['']+list(series.index))

    pos = nx.layout.spring_layout(g)

    if mode=='both':
        
        node_sizes = [100]+list(series.values.ravel())
        edge_colors =list(map(math.log,series.values.ravel()))    
        nodes = nx.draw_networkx_nodes(g,pos,node_size=node_sizes,node_color=node_color)
        edges = nx.draw_networkx_edges(g,pos,node_size=node_sizes,arrowstyle='->',arrowsize=10,width = 2,edge_cmap = plt.cm.winter,edge_color=edge_colors)
        pc = mpl.collections.PatchCollection(edges,cmap=plt.cm.winter)
        pc.set_array(edge_colors)
        plt.colorbar(pc)

    # edge_colors=range(2,g.number_of_edges()+2 )
    elif mode=='edge':
        edge_colors =list(map(math.log,series.values.ravel()))
        nodes = nx.draw_networkx_nodes(g,pos,node_color=node_color)
        node_sizes = [100]+list(series.values.ravel())

        edges = nx.draw_networkx_edges(g,pos,node_size=node_sizes,arrowstyle='->',arrowsize=10,width = 2,edge_cmap = plt.cm.winter,edge_color=edge_colors)
        pc = mpl.collections.PatchCollection(edges,cmap=plt.cm.winter)
        pc.set_array(edge_colors)
        plt.colorbar(pc)
    elif mode=='node':
        node_sizes = [100]+list(series.values.ravel())
        nodes = nx.draw_networkx_nodes(g,pos,node_size=node_sizes,node_color=node_color)
        edges = nx.draw_networkx_edges(g,pos,node_size=node_sizes,arrowstyle='->',arrowsize=10,width = 2)

    labels = nx.draw_networkx_labels(g,pos,labels=labs,font_color=font_color)



    ax = plt.gca()
    ax.set_axis_off()
    fig = plt.gcf()
    fig.set_size_inches(14,10)
    plt.title("Categories of product to france by count.")
    plt.show()

# %%
origins_france = origins_split[origins_split["origins_tags"] == "france"]
z = origins_france.join(data,lsuffix="l",rsuffix="r")

# %%
z["countries"].value_counts()
# Export analysis is null......
# Out:
# France          12600
# en:france        1761
# en:FR             352
# Frankreich          2
# en:FR,France        2
# Франция             1
# Francia             1
# Frankrijk           1
# france              1
# Name: countries, dtype: int64

# %%
data_origin = pd.read_csv("data/Origine-Coordinate-raw.csv")

# %%
data_origin.head()
# Out:
#          Unnamed: 0  origins_tags           origine  \
# 0            france         11051            france
# 1  union-europeenne          1986  union-europeenne
# 2            italie           969            italie
# 3           espagne           889           espagne
# 4            mexico           814            mexico
#
#                                                Coord  \
# 0                      France métropolitaine, France
# 1  European Union, Άμπελος, Δήμος Γαύδου, Περιφερ...
# 2                                             Italia
# 3                                             España
# 4        Ciudad de México, Cuauhtémoc, 06060, México
#
#                                 Point    Coord_x    Coord_y
# 0         (46.603354, 1.8883335, 0.0)  46.603354   1.888333
# 1  (34.8696391, 24.068801347645, 0.0)  34.869639  24.068801
# 2        (42.6384261, 12.674297, 0.0)  42.638426  12.674297
# 3       (39.3262345, -4.8380649, 0.0)  39.326234  -4.838065
# 4      (19.4326009, -99.1333416, 0.0)  19.432601 -99.133342

# %%
t = data_origin.iloc[0,:]
tp = gp.Point(t.Coord_x,t.Coord_y)
z = data_origin.iloc[1,:]
zp = gp.Point(z.Coord_x,z.Coord_y)

# %%
distance.distance(tp,zp).km
data_origin.head()
# Out:
#   Unnamed: 0  manufacturing_places_tags    origine  \
# 0     france                      18599     france
# 1     italie                       2428     italie
# 2   belgique                       1420   belgique
# 3     suisse                       1258     suisse
# 4  allemagne                       1246  allemagne
#
#                             Coord                          Point    Coord_x  \
# 0   France métropolitaine, France    (46.603354, 1.8883335, 0.0)  46.603354
# 1                          Italia   (42.6384261, 12.674297, 0.0)  42.638426
# 2     België / Belgique / Belgien   (50.6402809, 4.6667145, 0.0)  50.640281
# 3  Schweiz/Suisse/Svizzera/Svizra   (46.7985624, 8.2319736, 0.0)  46.798562
# 4             Deutschland, Europe  (51.0834196, 10.4234469, 0.0)  51.083420
#
#      Coord_y
# 0   1.888333
# 1  12.674297
# 2   4.666714
# 3   8.231974
# 4  10.423447

# %%
data["origine"] = data["origins_tags"]

# %%
data_1 = data.merge(data_origin,on=['origine'])
data_1.head()
# Out:
#                                                  url  \
# 0  http://world-en.openfoodfacts.org/product/0000...
# 1  http://world-en.openfoodfacts.org/product/0000...
# 2  http://world-en.openfoodfacts.org/product/0000...
# 3  http://world-en.openfoodfacts.org/product/0000...
# 4  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0                     kiliweb  1514659309  2017-12-30T18:41:49Z
# 1                    bcatelin  1409411252  2014-08-30T15:07:32Z
# 2                  agamitsudo  1474099741  2016-09-17T08:09:01Z
# 3  openfoodfacts-contributors  1537981553  2018-09-26T17:05:53Z
# 4  openfoodfacts-contributors  1415119256  2014-11-04T16:40:56Z
#
#   last_modified_t last_modified_datetime                       product_name  \
# 0      1535310176   2018-08-26T19:02:56Z  Blanquette de Volaille et son Riz
# 1      1461437669   2016-04-23T18:54:29Z                              Flute
# 2      1501529116   2017-07-31T19:25:16Z       Côtes du Rhône Villages 2014
# 3      1537984282   2018-09-26T17:51:22Z                     Reese's sticks
# 4      1428327438   2015-04-06T13:37:18Z                   Chair à saucisse
#
#                         generic_name quantity             packaging    ...     \
# 0  Blanquette de Volaille et son Riz      NaN      carton,plastique    ...
# 1                              Flute      NaN    Paper,plastic film    ...
# 2                                NaN  75 cl e    Verre,71,Bouteille    ...
# 3                                NaN   2,20 g  en barre de chocolat    ...
# 4                                NaN    792 g   Barquette,Plastique    ...
#
#   beta-glucan_100g inositol_100g carnitine_100g origine Unnamed: 0  \
# 0              NaN           NaN            NaN  france     france
# 1              NaN           NaN            NaN  france     france
# 2              NaN           NaN            NaN  france     france
# 3              NaN           NaN            NaN  france     france
# 4              NaN           NaN            NaN  france     france
#
#   manufacturing_places_tags_y                          Coord  \
# 0                       18599  France métropolitaine, France
# 1                       18599  France métropolitaine, France
# 2                       18599  France métropolitaine, France
# 3                       18599  France métropolitaine, France
# 4                       18599  France métropolitaine, France
#
#                          Point    Coord_x   Coord_y
# 0  (46.603354, 1.8883335, 0.0)  46.603354  1.888333
# 1  (46.603354, 1.8883335, 0.0)  46.603354  1.888333
# 2  (46.603354, 1.8883335, 0.0)  46.603354  1.888333
# 3  (46.603354, 1.8883335, 0.0)  46.603354  1.888333
# 4  (46.603354, 1.8883335, 0.0)  46.603354  1.888333
#
# [5 rows x 180 columns]

# %%
data_1["manufacturing_places"]

# %% [markdown]
# ## Category <\--> distance computations

# %%
data.head()
# Out:
#                                                              url   creator  \
# code
# 0000000000017  http://world-en.openfoodfacts.org/product/0000...   kiliweb
# 0000000000031  http://world-en.openfoodfacts.org/product/0000...  isagoofy
# 0000000000123  http://world-en.openfoodfacts.org/product/0000...   kiliweb
# 0000000000291  http://world-en.openfoodfacts.org/product/0000...   kiliweb
# 0000000000949  http://world-en.openfoodfacts.org/product/0000...   kiliweb
#
#                 created_t      created_datetime last_modified_t  \
# code
# 0000000000017  1529059080  2018-06-15T10:38:00Z      1529059204
# 0000000000031  1539464774  2018-10-13T21:06:14Z      1539464817
# 0000000000123  1535737982  2018-08-31T17:53:02Z      1535737986
# 0000000000291  1534239669  2018-08-14T09:41:09Z      1534239732
# 0000000000949  1523440813  2018-04-11T10:00:13Z      1523440823
#
#               last_modified_datetime               product_name generic_name  \
# code
# 0000000000017   2018-06-15T10:40:04Z           Vitória crackers          NaN
# 0000000000031   2018-10-13T21:06:57Z                      Cacao          NaN
# 0000000000123   2018-08-31T17:53:06Z      Sauce Sweety chili 0%          NaN
# 0000000000291   2018-08-14T09:42:12Z                  Mendiants          NaN
# 0000000000949   2018-04-11T10:00:23Z  Salade de carottes râpées          NaN
#
#               quantity packaging   ...   nutrition-score-fr_100g  \
# code                               ...
# 0000000000017      NaN       NaN   ...                       NaN
# 0000000000031    130 g       NaN   ...                       NaN
# 0000000000123      NaN       NaN   ...                       NaN
# 0000000000291      NaN       NaN   ...                       NaN
# 0000000000949      NaN       NaN   ...                       NaN
#
#               nutrition-score-uk_100g glycemic-index_100g water-hardness_100g  \
# code
# 0000000000017                     NaN                 NaN                 NaN
# 0000000000031                     NaN                 NaN                 NaN
# 0000000000123                     NaN                 NaN                 NaN
# 0000000000291                     NaN                 NaN                 NaN
# 0000000000949                     NaN                 NaN                 NaN
#
#               choline_100g phylloquinone_100g beta-glucan_100g inositol_100g  \
# code
# 0000000000017          NaN                NaN              NaN           NaN
# 0000000000031          NaN                NaN              NaN           NaN
# 0000000000123          NaN                NaN              NaN           NaN
# 0000000000291          NaN                NaN              NaN           NaN
# 0000000000949          NaN                NaN              NaN           NaN
#
#               carnitine_100g origine
# code
# 0000000000017            NaN     NaN
# 0000000000031            NaN     NaN
# 0000000000123            NaN     NaN
# 0000000000291            NaN     NaN
# 0000000000949            NaN     NaN
#
# [5 rows x 174 columns]

# %%
z = data
z = z[["categories_en"]]
z = z["categories_en"].str.split(',').apply(pd.Series).unstack().dropna().to_frame()
z = z.reset_index().set_index('code')
z.columns = ['','categories_en']
categories_split = z[['categories_en']]
categories_split.head()
# Out:
#                                  categories_en
# code
# 0000000001281                             Pies
# 0000000001885  Plant-based foods and beverages
# 0000000005470  Plant-based foods and beverages
# 0000000005661                          Seafood
# 0000000020114              Dietary supplements

# %%
cat_data = categories_split.join(data,lsuffix='_l',rsuffix='_r')

# %%
cat_data_w_origin = cat_data.reset_index().merge(data_origin,on=["origine"])

# %%
cat_data_w_origin.head()
# Out:
#             code      categories_en_l  \
# 0  0000000274722                Meals
# 1  0000000274722  Meat-based products
# 2  0000000274722      Meals with meat
# 3  0000000274722      Microwave meals
# 4  0000000274722        Poultry meals
#
#                                                  url  creator   created_t  \
# 0  http://world-en.openfoodfacts.org/product/0000...  kiliweb  1514659309
# 1  http://world-en.openfoodfacts.org/product/0000...  kiliweb  1514659309
# 2  http://world-en.openfoodfacts.org/product/0000...  kiliweb  1514659309
# 3  http://world-en.openfoodfacts.org/product/0000...  kiliweb  1514659309
# 4  http://world-en.openfoodfacts.org/product/0000...  kiliweb  1514659309
#
#        created_datetime last_modified_t last_modified_datetime  \
# 0  2017-12-30T18:41:49Z      1535310176   2018-08-26T19:02:56Z
# 1  2017-12-30T18:41:49Z      1535310176   2018-08-26T19:02:56Z
# 2  2017-12-30T18:41:49Z      1535310176   2018-08-26T19:02:56Z
# 3  2017-12-30T18:41:49Z      1535310176   2018-08-26T19:02:56Z
# 4  2017-12-30T18:41:49Z      1535310176   2018-08-26T19:02:56Z
#
#                         product_name                       generic_name  \
# 0  Blanquette de Volaille et son Riz  Blanquette de Volaille et son Riz
# 1  Blanquette de Volaille et son Riz  Blanquette de Volaille et son Riz
# 2  Blanquette de Volaille et son Riz  Blanquette de Volaille et son Riz
# 3  Blanquette de Volaille et son Riz  Blanquette de Volaille et son Riz
# 4  Blanquette de Volaille et son Riz  Blanquette de Volaille et son Riz
#
#      ...    beta-glucan_100g inositol_100g carnitine_100g origine Unnamed: 0  \
# 0    ...                 NaN           NaN            NaN  france     france
# 1    ...                 NaN           NaN            NaN  france     france
# 2    ...                 NaN           NaN            NaN  france     france
# 3    ...                 NaN           NaN            NaN  france     france
# 4    ...                 NaN           NaN            NaN  france     france
#
#   manufacturing_places_tags_y                          Coord  \
# 0                       18599  France métropolitaine, France
# 1                       18599  France métropolitaine, France
# 2                       18599  France métropolitaine, France
# 3                       18599  France métropolitaine, France
# 4                       18599  France métropolitaine, France
#
#                          Point    Coord_x   Coord_y
# 0  (46.603354, 1.8883335, 0.0)  46.603354  1.888333
# 1  (46.603354, 1.8883335, 0.0)  46.603354  1.888333
# 2  (46.603354, 1.8883335, 0.0)  46.603354  1.888333
# 3  (46.603354, 1.8883335, 0.0)  46.603354  1.888333
# 4  (46.603354, 1.8883335, 0.0)  46.603354  1.888333
#
# [5 rows x 182 columns]
