# %%
import pandas as pd
import numpy as np
import scipy as scp
import geopy # pip install geopy if necessary

# %%
data = pd.read_csv('../openfoodfacts.csv',delimiter='\t',low_memory=False)

# %%
print(data.shape)
# Out:
# (665697, 174)

# %% [markdown]
# # Data for distance computation

# %%
#a = ~data["first_packaging_code_geo"].isnull() # 27572
b = ~data["origins_tags"].isnull()
c = ~data["manufacturing_places_tags"].isnull()

sele = b | c  # 88001

data_loc = data[sele] # 57688 (88001)

sel = ['categories_en', 'main_category_en', 'labels_en', 'origins_tags', 'manufacturing_places_tags', 
       'first_packaging_code_geo', 'countries_en']

data_loc = data_loc[sel]
data_loc
# Out:
#                                             categories_en  \
# 96                                    Dietary supplements
# 238     Meals,Meat-based products,Meals with meat,Micr...
# 241     Plant-based foods and beverages,Plant-based fo...
# 254             Sugary snacks,Biscuits and cakes,Pastries
# 259     Plant-based foods and beverages,Plant-based fo...
# 264             Sugary snacks,Biscuits and cakes,Pastries
# 276                                           fr:Boulange
# 280     Beverages,Carbonated drinks,Sodas,Sugared beve...
# 284     Sugary snacks,Biscuits and cakes,Biscuits,fr:S...
# 288     Meals,Pizzas pies and quiches,Quiches,Lorraine...
# 289               Meats,Poultries,Chickens,Cooked chicken
# 291                 Sugary snacks,Confectioneries,Candies
# 297     Plant-based foods and beverages,Beverages,Plan...
# 334             Sugary snacks,Biscuits and cakes,Pastries
# 336                                          Chicken-feet
# 342     Beverages,Alcoholic beverages,Wines,French-win...
# 369     Plant-based foods and beverages,Plant-based fo...
# 389                  Desserts,Puddings,Christmas Puddings
# 390     Sugary snacks,Desserts,Biscuits and cakes,Cake...
# 396                                                   NaN
# 492     Plant-based foods and beverages,Plant-based fo...
# 507                  Groceries,Condiments,Sauces,Mustards
# 517     Sugary snacks,Desserts,Biscuits and cakes,Cake...
# 536     Plant-based foods and beverages,Plant-based fo...
# 553     Dietary supplements,Bodybuilding supplements,P...
# 554     Dietary supplements,Bodybuilding supplements,P...
# 565     Dietary supplements,Bodybuilding supplements,P...
# 571     Sugary snacks,Biscuits and cakes,Cakes,fr:Cake...
# 576     Sugary snacks,Desserts,Biscuits and cakes,Cake...
# 577                                            Meats,Pork
# ...                                                   ...
# 665312     Salty snacks,Appetizers,Chips and fries,Crisps
# 665323                                fr:Boissons-au-soja
# 665353                                                NaN
# 665361                                   es:Sauce-a-l-ail
# 665370  Sugary snacks,Biscuits and cakes,Biscuits,Bisc...
# 665405  Canned foods,Seafood,Fishes,Canned fishes,Tuna...
# 665418                   Groceries,Sauces,Salad dressings
# 665419                   Groceries,Sauces,Salad dressings
# 665450                                         Sandwiches
# 665469  Beverages,Waters,Non-sugared beverages,Non-Alc...
# 665470                       Sugary snacks,Popcorn,Snacks
# 665491                             Seafood,Fishes,Salmons
# 665530         fr:Attieke,fr:Manioc,fr:Semoules-de-manioc
# 665532  Beverages,Alcoholic beverages,Artisan products...
# 665533                      Beverages,Alcoholic beverages
# 665534  Beverages,Alcoholic beverages,Artisan products...
# 665543  Plant-based foods and beverages,Plant-based fo...
# 665554  Plant-based foods and beverages,Beverages,Plan...
# 665568  Plant-based foods and beverages,Plant-based fo...
# 665577                                                NaN
# 665579  Plant-based foods and beverages,Plant-based fo...
# 665595         Beverages,Alcoholic beverages,Beers,Lagers
# 665597  Sugary snacks,Biscuits and cakes,Biscuits,Choc...
# 665606              Desserts,Frozen foods,Frozen desserts
# 665617  Breakfasts,Spreads,Sweet spreads,Bee products,...
# 665625  Dairies,Fermented foods,Fermented milk product...
# 665634  Beverages,Alcoholic beverages,Wines,Wines from...
# 665636                                          pl:Szprot
# 665637  Plant-based foods and beverages,Beverages,Plan...
# 665681  Plant-based foods and beverages,Plant-based fo...
#
#                        main_category_en  \
# 96                  Dietary supplements
# 238                               Meals
# 241     Plant-based foods and beverages
# 254                       Sugary snacks
# 259     Plant-based foods and beverages
# 264                       Sugary snacks
# 276                         fr:Boulange
# 280                           Beverages
# 284                       Sugary snacks
# 288                               Meals
# 289                               Meats
# 291                       Sugary snacks
# 297                           Beverages
# 334                       Sugary snacks
# 336                        Chicken-feet
# 342                           Beverages
# 369     Plant-based foods and beverages
# 389                            Desserts
# 390                       Sugary snacks
# 396                                 NaN
# 492     Plant-based foods and beverages
# 507                           Groceries
# 517                       Sugary snacks
# 536     Plant-based foods and beverages
# 553                 Dietary supplements
# 554                 Dietary supplements
# 565                 Dietary supplements
# 571                       Sugary snacks
# 576                       Sugary snacks
# 577                               Meats
# ...                                 ...
# 665312                     Salty snacks
# 665323              fr:Boissons-au-soja
# 665353                              NaN
# 665361                 es:Sauce-a-l-ail
# 665370                    Sugary snacks
# 665405                     Canned foods
# 665418                        Groceries
# 665419                        Groceries
# 665450                       Sandwiches
# 665469                        Beverages
# 665470                    Sugary snacks
# 665491                          Seafood
# 665530                       fr:Attieke
# 665532                        Beverages
# 665533                        Beverages
# 665534                        Beverages
# 665543  Plant-based foods and beverages
# 665554                     Fruit juices
# 665568                        Groceries
# 665577                              NaN
# 665579  Plant-based foods and beverages
# 665595                        Beverages
# 665597                    Sugary snacks
# 665606                         Desserts
# 665617                       Breakfasts
# 665625                          Dairies
# 665634                        Beverages
# 665636                        pl:Szprot
# 665637                     Fruit juices
# 665681  Plant-based foods and beverages
#
#                                                 labels_en  \
# 96                                         Made in France
# 238                    fr:Viande Française,Made in France
# 241                                                   NaN
# 254                                                   NaN
# 259                                                   NaN
# 264                                                   NaN
# 276                                                   NaN
# 280                                  Kosher,Contains GMOs
# 284                                             Green Dot
# 288                                                   NaN
# 289                                                   NaN
# 291                   No artificial flavors,Contains GMOs
# 297                                                   NaN
# 334                                                   NaN
# 336                               Incorrect data on label
# 342     Not advised for specific people,PDO,Made in Fr...
# 369     Sustainable farming,UTZ Certified,UTZ Certifie...
# 389                                                   NaN
# 390                                                   NaN
# 396                                                   NaN
# 492                                                   NaN
# 507                                      Vegetarian,Vegan
# 517                                                   NaN
# 536                                                   NaN
# 553                                                   NaN
# 554                                                   NaN
# 565                                                   NaN
# 571                              Green Dot,Made in France
# 576                              Green Dot,Made in France
# 577                                                   NaN
# ...                                                   ...
# 665312                                                NaN
# 665323  de:Halal,fr:Analyse-des-dangers-et-points-crit...
# 665353                                                NaN
# 665361  es:Peu-ou-pas-de-sucre,es:Sans-gluten,es:Sans-...
# 665370                                                NaN
# 665405  Dolphin-friendly,Fished-by-pole-line,Recyclabl...
# 665418                                         Vegetarian
# 665419                                         Vegetarian
# 665450                                   Vegetarian,Vegan
# 665469                                                NaN
# 665470                            Gluten-free,High fibres
# 665491                                                NaN
# 665530                                                NaN
# 665532  Carbon footprint,Carbon footprint,Carbon footp...
# 665533                                                NaN
# 665534  Carbon footprint,Carbon footprint,Carbon footp...
# 665543    Organic,EU Organic,fr:AB Agriculture Biologique
# 665554                                                NaN
# 665568                                                NaN
# 665577                                                NaN
# 665579                                        Gluten-free
# 665595  Not advised for specific people,Green Dot,Not ...
# 665597         No preservatives,fr:Fabrication artisanale
# 665606                                          Green Dot
# 665617                                                NaN
# 665625                                                PDO
# 665634                                             fr:AOC
# 665636                                                NaN
# 665637                                                NaN
# 665681                                                NaN
#
#                                          origins_tags  \
# 96                                                NaN
# 238                                            france
# 241                                            quebec
# 254                                            quebec
# 259                                            france
# 264                                            quebec
# 276                                            quebec
# 280                                               NaN
# 284                                               NaN
# 288                                            quebec
# 289                                            quebec
# 291                                               NaN
# 297                                               NaN
# 334                                     quebec,canada
# 336                                               NaN
# 342                                            france
# 369                                               NaN
# 389                                               NaN
# 390                                               NaN
# 396                                            france
# 492                                    united-kingdom
# 507                                               NaN
# 517                                               NaN
# 536                                           germany
# 553                                           germany
# 554                                           germany
# 565                                           germany
# 571                                               NaN
# 576                                               NaN
# 577                                            france
# ...                                               ...
# 665312                                            NaN
# 665323                                            NaN
# 665353                                            NaN
# 665361  comunidad-valenciana,benifaio,valencia,espana
# 665370                                            NaN
# 665405                                            NaN
# 665418                                            NaN
# 665419                                            NaN
# 665450                                            NaN
# 665469                                            NaN
# 665470                                         canada
# 665491                                         norway
# 665530                                  cote-d-ivoire
# 665532                                            NaN
# 665533                                         france
# 665534                                            NaN
# 665543                                        tunisie
# 665554                                     madagascar
# 665568                                      sri-lanka
# 665577                                            NaN
# 665579                                         france
# 665595                                            NaN
# 665597                                            NaN
# 665606                                            NaN
# 665617                                france,camargue
# 665625                                       lait-cru
# 665634                              flaxieu,bugey,ain
# 665636                                         polska
# 665637                  saint-jans-cappel,nord,france
# 665681                                       inconnue
#
#                                 manufacturing_places_tags  \
# 96                                                 france
# 238                                                france
# 241                                       brossard-quebec
# 254                                       brossard-quebec
# 259                                        united-kingdom
# 264                                       brossard-quebec
# 276                                       brossard,quebec
# 280                                            etats-unis
# 284                                      france,avranches
# 288                                       brossard,quebec
# 289                                       brossard-quebec
# 291                                            etats-unis
# 297                                                france
# 334                                       brossars,quebec
# 336                                              thailand
# 342                                                france
# 369                                               belgien
# 389                                        united-kingdom
# 390                                        united-kingdom
# 396                                                net-wt
# 492                                                   NaN
# 507     las-ventas-de-retamosa,toledo-provincia,castil...
# 517                                   saint-yrieix,france
# 536                                                   NaN
# 553                                               germany
# 554                                               germany
# 565                                               germany
# 571                                                france
# 576                    france,limousin,87500,saint-yrieux
# 577                                                france
# ...                                                   ...
# 665312                                           malaisie
# 665323                                           malaisie
# 665353                                                 eu
# 665361      benifaio,valencia,comunidad-valenciana,espana
# 665370                                              macao
# 665405                                              spain
# 665418                                     united-kingdom
# 665419                                     united-kingdom
# 665450                                             suisse
# 665469                                            ontario
# 665470                                                NaN
# 665491                                                NaN
# 665530                                                NaN
# 665532                      le-mouchet,drome-des-collines
# 665533  biere-brassee-au-chateau-du-mouchet-a-chavanne...
# 665534                             chavannes-26260,france
# 665543                                                NaN
# 665554                                         madagascar
# 665568                                                NaN
# 665577                   antartic-45110-st-martin-d-abbat
# 665579                                             italie
# 665595       carib-brewery-ltd,champs-fleurs,trinidad,w-i
# 665597                                  versailles,france
# 665606                                             france
# 665617                                             france
# 665625                           moissac-vallee-francaise
# 665634                                                NaN
# 665636                                                NaN
# 665637                                                NaN
# 665681                                            hongrie
#
#        first_packaging_code_geo  \
# 96                          NaN
# 238                         NaN
# 241                         NaN
# 254                         NaN
# 259                         NaN
# 264                         NaN
# 276                         NaN
# 280                         NaN
# 284                         NaN
# 288                         NaN
# 289                         NaN
# 291                         NaN
# 297                         NaN
# 334                         NaN
# 336                         NaN
# 342                         NaN
# 369                         NaN
# 389                         NaN
# 390                         NaN
# 396                         NaN
# 492                         NaN
# 507                         NaN
# 517                         NaN
# 536                         NaN
# 553                         NaN
# 554                         NaN
# 565                         NaN
# 571                         NaN
# 576                         NaN
# 577          43.783333,0.983333
# ...                         ...
# 665312                      NaN
# 665323                      NaN
# 665353                      NaN
# 665361                      NaN
# 665370                      NaN
# 665405                      NaN
# 665418                      NaN
# 665419                      NaN
# 665450                      NaN
# 665469                      NaN
# 665470                      NaN
# 665491                      NaN
# 665530                      NaN
# 665532                      NaN
# 665533                      NaN
# 665534                      NaN
# 665543                      NaN
# 665554                      NaN
# 665568                      NaN
# 665577           47.85,2.266667
# 665579                      NaN
# 665595                      NaN
# 665597                      NaN
# 665606          46.166667,-1.15
# 665617       43.666667,4.633333
# 665625                      NaN
# 665634                      NaN
# 665636                      NaN
# 665637                      NaN
# 665681                      NaN
#
#                                              countries_en
# 96                                                 France
# 238                                                France
# 241                                                Canada
# 254                                                Canada
# 259                                        United Kingdom
# 264                                                Canada
# 276                                                Canada
# 280                                  France,United States
# 284                                                France
# 288                                                Canada
# 289                                                Canada
# 291                                                France
# 297                                                France
# 334                                                Canada
# 336                                        United Kingdom
# 342                                                France
# 369                                               Germany
# 389                                        United Kingdom
# 390                                        United Kingdom
# 396                                                France
# 492                                        United Kingdom
# 507                                                 Spain
# 517                                                France
# 536                                        United Kingdom
# 553                                               Germany
# 554                                               Germany
# 565                                               Germany
# 571                                                France
# 576                                                France
# 577                                                France
# ...                                                   ...
# 665312  Algeria,Egypt,Malaysia,Morocco,Saudi Arabia,Sy...
# 665323                                             France
# 665353                                             France
# 665361                                              Spain
# 665370                                   France,Hong Kong
# 665405                                     United Kingdom
# 665418                                     United Kingdom
# 665419                                     United Kingdom
# 665450                                        Switzerland
# 665469                                      United States
# 665470                                             Canada
# 665491                                             France
# 665530                                             France
# 665532                                             France
# 665533                                             France
# 665534                                             France
# 665543                                             France
# 665554                                         Madagascar
# 665568                                             France
# 665577                                         Martinique
# 665579                                             France
# 665595                                                NaN
# 665597                                             France
# 665606                                             France
# 665617                                             France
# 665625                                             France
# 665634                                             France
# 665636                                             Poland
# 665637                                             France
# 665681                                             France
#
# [78517 rows x 7 columns]

# %% [markdown]
# ## Pre-process on coutrnies_en section

# %% [markdown]
# Sometimes the countries_en section contains several countries. Thus duplications of the product have to be done in order to consider the product in each country independantly.

# %%
z = data_loc["countries_en"].str.split(',').apply(pd.Series)
z1 = z.unstack().dropna()
z1 = z1.to_frame()

# %%
z1.columns = ['destination']

# %%
# change destination with special characters
# manually checked on wikipedia + google maps
z1[z1['destination'] == 'Other-日本'] = 'Japon' # manually checked on wiki
z1[z1['destination'] == '中国'] = 'Chine'
z1[z1['destination'] == 'fr:香港'] = 'Hong Kong'
z1[z1['destination'] == 'fr:日本'] = 'Japon'
z1[z1['destination'] == 'Ελλάδα'] = 'Grèce'
z1[z1['destination'] == 'ar:صنعاء'] = 'Sanaa'
z1[z1['destination'] == 'fr:الجزائر'] = 'Algérie'

# %%
# remove fr: or others xx: in destination
def split_xx(l):
    tmp = l.split(':')
    
    if len(tmp) == 1:
        return l
    else:
        return tmp[1]
        
    #.str.get(0).str[1,:]
        
z1['destination'] = z1['destination'].apply(lambda l: split_xx(l))

# %%
print(z1.shape)
z1 = z1[~(z1 == 'Photos uploaded')]
z1 = z1[~(z1 == 'Photos validated')]
z1 = z1[~(z1 == 'Product name completed')]
z1 = z1[~(z1 == 'Photos to be uploaded')]
z1 = z1[~(z1 == 'Photos to be validated')]
z1 = z1[~(z1 == 'Quantity completed')]
z1 = z1[~(z1 == 'Nutrition facts completed')]
z1 = z1[~(z1 == 'Ingredients completed')]
z1 = z1[~(z1 == 'Brands completed')]
z1 = z1[~(z1 == 'Packaging completed')]
z1 = z1[~(z1 == 'Characteristics completed')]
z1 = z1[~(z1 == 'Categories completed')]
z1 = z1[~(z1 == 'Packaging-code-completed')]
z1 = z1[~(z1 == 'Expiration date completed')]
z1 = z1[~(z1 == 'Expiration date to be completed')]
z1 = z1[~(z1 == 'En')]
z1 = z1[~(z1 == 'To be completed')]
z1 = z1[~(z1 == 'To be checked')]
z1 = z1[~(z1 == 'Worldwide')]
z1 = z1[~(z1 == 'World')]
z1 = z1[~(z1 == 'Sucre')]
z1 = z1[~(z1 == 'Complete')]
z1 = z1[~(z1 == 'Global-market')]
z1 = z1[~(z1 == 'Dat')]
z1 = z1[~(z1 == 'France-others')]

z1 = z1.dropna()
print(z1.shape)
#z1 = z1.to_frame()

# %%
# replace values manually
z1[z1['destination'] == 'Leclerc-bois-d-arcy-france'] = 'France'
z1[z1['destination'] == 'Francecontient-des-sulfites'] = 'France'
z1[z1['destination'] == 'Leclerc'] = 'France'
z1[z1['destination'] == 'Auchan'] = 'France'
z1[z1['destination'] == 'Carrefour'] = 'France'
z1[z1['destination'] == 'Estadps-unidos'] = 'United States'
z1[z1['destination'] == 'Polyensie-francaise'] = 'French Polynesia'

# %%
z1 = z1.swaplevel()
z1 = z1.reset_index(level=1, drop=True)

# %%
z1.head()

# %% [markdown]
# Apply the dictionnary to translate all countries in english

# %% [markdown]
# ## Select french products

# %%
countries = pd.read_csv('data/Destination-Coordinate-MAN.csv',delimiter=',',low_memory=False)
dico_countries = dict(zip(countries['destination'], countries['country']))

# %%
dico_countries

# %%
z1['Arrival'] = z1['destination'].apply(lambda l: dico_countries[l])
z1.head()

# %%
selection = z1[z1['Arrival'] == 'France']

# %%
selection.shape

# %%
selection.head()

# %%
selection.index

# %%
french_product = data_loc.loc[selection.index]
french_product.head()

# %%
french_product.to_csv('data/FrenchProduct.csv')

# %%
# check
country_count = french_product["countries_en"].value_counts()[0:20]
country_count
